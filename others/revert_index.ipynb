# %% [markdown]
# ### 1. Ler os documentos e recuperar cada par (**wordId**, **documentId**)

# %%
for cont in range(0, 44):
    filename = open("..//dataset//{}".format(cont), 'r', enconding='cp1252').read()

# %% [markdown]
# ### Etapa 2: Limpar os caracteres inúteis

# %%
for remove in '!@#$%&*()<>:;,./?\|[]{}=+':
    texto = texto.replace(remove, '')

# %% [markdown]
# #### Exibir conteúdo do arquivo

# %%
# retirado 173.822 caracteres inúteis
print(len(texto))
# Out:
# 4342764

# %%
import os

def main():
    path = "c//Users//p22.ribeiro//ubuntu2004//repocode//challenge-python//dataset//50.txt"
    dirs = os.listdir(path)
    
    for filename in dirs:
        if filename.endswith(""):
            print(os.path.join(path,filename))
'''        
    frase = filename.read().lower()
            
    for remove in '!@#$%&*()<>:;,./?\|[]{}=+':
        frase = frase.replace(remove, '')


    lista_frase = frase.split()
    comprimento = len(lista_frase)
    ultima = comprimento -1

    #print(len(lista_frase))
    print(comprimento)

    indice = 0
    while indice < comprimento:
        for palavra in lista_frase:
            #print(palavra)
            dicionario_palavra = {indice, palavra}

            print(dicionario_palavra)
        #print(indice, lista_frase)
            indice += 1
'''        
main()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-85-e661e1e1157b> in <module>
#      32             indice += 1
#      33 '''
# ---> 34 main()
#
# <ipython-input-85-e661e1e1157b> in main()
#       3 def main():
#       4     path = "c//Users//p22.ribeiro//ubuntu2004//repocode//challenge-python//dataset//50.txt"
# ----> 5     dirs = os.listdir(path)
#       6
#       7     for filename in dirs:
#
# FileNotFoundError: [WinError 3] O sistema não pode encontrar o caminho especificado: 'c//Users//p22.ribeiro//ubuntu2004//repocode//challenge-python//dataset//50.txt'

# %%
print(lista_frase)
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
# ```py
def main():
    for cont in range(0 ,44):
        with open("C:\\Users\\p22.ribeiro\\OneDrive\\repocode\\challenge-python\\dataset\\{}".format(0), "r", encoding="cp1252") as arquivo:
            frase = arquivo.read()
                 
    for remove in '!@#$%&*()<>:;,./?\|][}{=+-"':
        frase = frase.replace(remove, ' ').lower()

    lista_frase = frase.split()
    clear_list = set(lista_frase)
    clear_list = sorted(clear_list)
    comprimento = len(clear_list)

    # print(lista_frase)
    # print(comprimento)

    indice = 0
    while indice < comprimento:
        for palavra in clear_list:
            dicionario_palavra = {indice, palavra}

            print(dicionario_palavra)
            indice += 1

main()
#```
# Out:
# {0, "'a"}
# {1, "'aduantage"}
# {"'anointed", 2}
# {3, "'beleeue"}
# {4, "'beseech"}
# {"'blesse", 5}
# {"'blessing", 6}
# {"'boue", 7}
# {8, "'bout"}
# {9, "'casion"}
# {10, "'chud"}
# {11, "'confounds"}
# {12, "'em"}
# {"'faith", 13}
# {"'foole", 14}
# {"'fore", 15}
# {16, "'gainst"}
# {17, "'ginne"}
# {"'gins", 18}
# {"'giue", 19}
# {"'good", 20}
# {21, "'greed"}
# {"'has", 22}
# {"'is", 23}
# {24, "'ist"}
# {25, "'lacke"}
# {26, "'marry"}
# {27, "'masse"}
# {28, "'masterly"}
# {29, "'may"}
# {"'mercie", 30}
# {"'midst", 31}
# {32, "'mong"}
# {33, "'mong'st"}
# {34, "'mongst"}
# {"'noynted", 35}
# {"'od's", 36}
# {37, "'ods"}
# {"'oman", 38}
# {"'ord", 39}
# {40, "'ords"}
# {41, "'please"}
# {42, "'plesse"}
# {43, "'pox"}
# {44, "'pray"}
# {45, "'pre"}
# {"'prethe", 46}
# {"'prethee", 47}
# {48, "'prythee"}
# {49, "'s"}
# {"'saue", 50}
# {"'sblud", 51}
# {"'shrew", 52}
# {"'so", 53}
# {"'t", 54}
# {"'tane", 55}
# {56, "'tas"}
# {57, "'tend"}
# {"'th'", 58}
# {59, "'this"}
# ...

# %% [markdown]
# ```py
# import os
# for file in os.listdir("/mydir"):
#     if file.endswith(".txt"):
#         print(os.path.join("/mydir", file))
# ```

# %% [markdown]
# ### 2. Ordenar cada par por <u>worldId</u> e <u>documentId</u>

# %% [markdown]
# ### 3. Para cada <u>worldId</u>, agrupar os pares, para ter a lista de documentos que contém a palavra

# %% [markdown]
# ### 4. Mesclar os resultados intermediários para ter o índice reverso final
